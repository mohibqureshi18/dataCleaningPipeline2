# %%
import numpy as np 
import pandas as pd

# %%
class LoadData:
    def __init__(self, file):
        self.file = file
        self.df = None

    def loadData(self):
        self.df = pd.read_csv(self.file)
        return self.df

# %%
class CleanData:

    def __init__(self, df):
        self.df = df

    def removeDuplicates(self):
        pass
    
    def handleMissingValues(self):
        pass

# %%
class EDA:

    def __init__(self, df, value):
        self.df = df
        self.value = value

    def data_info(self):
        pass

    def display_head(self, value):
        pass

    def display_tail(self, value):
        pass

    def total_missing_values(self):
        df.isnull().sum()

# %%
class VisualizeData:
    
    def __init__(self, df):
        self.df = df

    def histogram(self):
        pass

    def correlation_heatmap(self):
        pass
